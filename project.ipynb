# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from openpyxl.workbook import Workbook

# %%
import pandas as pd

# %%
import time
import datetime

# %%
import smtplib
from email.mime.multipart import MIMEMultipart

# %%
browser = webdriver.Chrome('/Users/mac/Downloads/chromedriver 4')

# %%
#Setting ticket types paths
return_ticket = "//label[@id='flight-type-roundtrip-label-hp-flight']"
one_way_ticket = "//label[@id='flight-type-one-way-label-hp-flight']"
multi_ticket = "//label[@id='flight-type-multi-dest-label-hp-flight']"

# %%
def ticket_chooser(ticket):
    try:
        ticket_type = browser.find_element_by_xpath(ticket)
        ticket_type.click()
    except Exception as e:
        pass

# %%
def dep_country_chooser(dep_country):
    fly_from = browser.find_element_by_xpath("//input[@id='flight-origin-hp-flight']")
    time.sleep(1)
    fly_from.clear()
    time.sleep(1.5)
    fly_from.send_keys('  ' + dep_country)
    time.sleep(1.5)
    first_item = browser.find_element_by_xpath("//a[@id='aria-option-0']")
    time.sleep(1.5)
    first_item.click()

# %%
def arrival_country_chooser(arrival_country):
    fly_to = browser.find_element_by_xpath("//input[@id='flight-destination-hp-flight']")
    time.sleep(1)
    fly_to.clear()
    time.sleep(1.5)
    fly_to.send_keys('  ' + arrival_country)
    time.sleep(1.5)
    #first_item = browser.find_element_by_xpath("//a[@id='aria-option-0']")
    #time.sleep(1.5)
    #first_item.click()

# %%
def dep_date_chooser(month, day, year):
    dep_date_button = browser.find_element_by_xpath("//input[@id='flight-departing-hp-flight']")
    dep_date_button.clear()
    dep_date_button.send_keys(month + '/' + day + '/' + year)

# %%
def return_date_chooser(month, day, year):
    return_date_button = browser.find_element_by_xpath("//input[@id='flight-returning-hp-flight']")
    for i in range(11):
        return_date_button.send_keys(Keys.BACKSPACE)
    return_date_button.send_keys(month + '/' + day + '/' + year)

# %%
def search():
    search = browser.find_element_by_xpath("//button[@class='btn-primary btn-action gcw-submit']")
    search.click()
    time.sleep(15)
    print('Results ready!')

# %%
df = pd.DataFrame()
def compile_data():
    global df
    global dep_times_list
    global arr_times_list
    global airlines_list
    global price_list
    global durations_list
    global stops_list
    global layovers_list
    #departure times
    dep_times = browser.find_elements_by_xpath("//span[@data-test-id='departure-time']")
    dep_times_list = [value.text for value in dep_times]
    #arrival times
    arr_times = browser.find_elements_by_xpath("//span[@data-test-id='arrival-time']")
    arr_times_list = [value.text for value in arr_times]
    #airline name
    airlines = browser.find_elements_by_xpath("//span[@data-test-id='airline-name']")
    airlines_list = [value.text for value in airlines]
    #prices
    prices = browser.find_elements_by_xpath("//span[@data-test-id='listing-price-dollars']")
    price_list = [value.text for value in prices]
    #durations
    durations = browser.find_elements_by_xpath("//span[@data-test-id='duration']")
    durations_list = [value.text for value in durations]
    #stops
    stops = browser.find_elements_by_xpath("//span[@class='number-stops']")
    stops_list = [value.text for value in stops]
    #layovers
    layovers = browser.find_elements_by_xpath("//span[@data-test-id='layover-airport-stops']")
    layovers_list = [value.text for value in layovers]
    now = datetime.datetime.now()
    current_date = (str(now.year) + '-' + str(now.month) + '-' + str(now.day))
    current_time = (str(now.hour) + ':' + str(now.minute))
    current_price = 'price' + '(' + current_date + '---' + current_time + ')'
    for i in range(len(dep_times_list)):
        try:
            df.loc[i, 'departure_time'] = dep_times_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, 'arrival_time'] = arr_times_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, 'airline'] = airlines_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, 'duration'] = durations_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, 'stops'] = stops_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, 'layovers'] = layovers_list[i]
        except Exception as e:
            pass
        try:
            df.loc[i, str(current_price)] = price_list[i]
        except Exception as e:
            pass
    print('Excel Sheet Created!')

# %%
for i in range(8):    
    link = 'https://www.expedia.co.in/'
    browser.get(link)
    time.sleep(5)
    #choose flights only
    flights_only = browser.find_element_by_xpath("//button[@id='tab-flight-tab-hp']")
    flights_only.click()
    ticket_chooser(return_ticket)
    dep_country_chooser('New Delhi')
    arrival_country_chooser('Mumbai')
    dep_date_chooser('15', '08', '2019')
    return_date_chooser('20', '08', '2019')
    search()
    compile_data()
    #save values for email
    current_values = df.iloc[0]
    cheapest_dep_time = current_values[0]
    cheapest_arrival_time = current_values[1]
    cheapest_airline = current_values[2]
    cheapest_duration = current_values[3]
    cheapest_stops = current_values[4]
    cheapest_price = current_values[-1]
    print('run {} completed!'.format(i))
    df.to_excel('flights.xlsx')
    time.sleep(3600)
# Out:
# Results ready!
# Excel Sheet Created!
# run 0 completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d9e4e60dd660> in <module>
#      23     print('run {} completed!'.format(i))
#      24     df.to_excel('flights.xlsx')
# ---> 25     time.sleep(3600)
#
# KeyboardInterrupt:

# %%
df.head(500)
# Out:
#    departure_time arrival_time   airline duration     stops  \
# 0           20:30        22:45  SpiceJet   2h 15m  (Direct)
# 1           19:45        22:05  SpiceJet   2h 20m  (Direct)
# 2           21:35        23:55  SpiceJet   2h 20m  (Direct)
# 3           18:35        20:50    IndiGo   2h 15m  (Direct)
# 4           21:30        23:50    IndiGo   2h 20m  (Direct)
# 5           19:40        22:00     GoAir   2h 20m  (Direct)
# 6           20:50        23:10     GoAir   2h 20m  (Direct)
# 7           15:00        17:10    IndiGo   2h 10m  (Direct)
# 8           06:40        08:55    IndiGo   2h 15m  (Direct)
# 9           19:30        21:45    IndiGo   2h 15m  (Direct)
# 10          20:25        22:40    IndiGo   2h 15m  (Direct)
# 11          22:30        00:45    IndiGo   2h 15m  (Direct)
# 12          05:35        07:45    IndiGo   2h 10m  (Direct)
# 13          07:30        09:40    IndiGo   2h 10m  (Direct)
# 14          17:30        19:40    IndiGo   2h 10m  (Direct)
# 15          04:50        07:10    IndiGo   2h 20m  (Direct)
# 16          18:35        20:45  SpiceJet   2h 10m  (Direct)
# 17          23:35        01:45  SpiceJet   2h 10m  (Direct)
# 18          15:50        18:05  SpiceJet   2h 15m  (Direct)
# 19          06:10        08:30  SpiceJet   2h 20m  (Direct)
# 20          19:00        21:10   Vistara   2h 10m  (Direct)
# 21          17:45        20:10   Vistara   2h 25m  (Direct)
# 22          07:00        09:15     GoAir   2h 15m  (Direct)
# 23          08:00        10:15     GoAir   2h 15m  (Direct)
# 24          10:35        12:50     GoAir   2h 15m  (Direct)
# 25          14:25        16:40     GoAir   2h 15m  (Direct)
# 26          18:20        20:35     GoAir   2h 15m  (Direct)
# 27          08:30        10:40    IndiGo   2h 10m  (Direct)
# 28          17:00        19:10    IndiGo   2h 10m  (Direct)
# 29          10:30        12:45    IndiGo   2h 15m  (Direct)
# ..            ...          ...       ...      ...       ...
# 53          17:40        09:35   Vistara  15h 55m  (1 stop)
# 54          14:50        21:55   Vistara    7h 5m  (1 stop)
# 55          18:55        23:59  SpiceJet    5h 4m  (1 stop)
# 56          07:10        13:50   Vistara   6h 40m  (1 stop)
# 57          20:45        09:35   Vistara  12h 50m  (1 stop)
# 58          14:50        09:35   Vistara  18h 45m  (1 stop)
# 59          20:45        21:55   Vistara  25h 10m  (1 stop)
# 60          12:50        15:00   Vistara   2h 10m  (Direct)
# 61          14:30        16:40   Vistara   2h 10m  (Direct)
# 62          10:20        12:35   Vistara   2h 15m  (Direct)
# 63          11:40        14:00   Vistara   2h 20m  (Direct)
# 64          07:10        21:55   Vistara  14h 45m  (1 stop)
# 65          07:10        09:35   Vistara  26h 25m  (1 stop)
# 66          17:10        23:20   Vistara   6h 10m  (1 stop)
# 67          16:50        21:25     GoAir   4h 35m  (1 stop)
# 68          07:10        18:20   Vistara  11h 10m  (1 stop)
# 69          08:10        16:05     GoAir   7h 55m  (1 stop)
# 70          15:10        22:45  SpiceJet   7h 35m  (1 stop)
# 71          07:20        16:05  SpiceJet   8h 45m  (1 stop)
# 72          12:00        20:20     GoAir   8h 20m  (1 stop)
# 73          11:10        17:25  SpiceJet   6h 15m  (1 stop)
# 74          11:30        18:55  SpiceJet   7h 25m  (1 stop)
# 75          16:05        21:45   Vistara   5h 40m  (1 stop)
# 76          17:35        23:20   Vistara   5h 45m  (1 stop)
# 77          07:15        14:30  SpiceJet   7h 15m  (1 stop)
# 78          07:15        13:05   Vistara   5h 50m  (1 stop)
# 79          05:55        14:20  SpiceJet   8h 25m  (1 stop)
# 80          08:05        13:20   Vistara   5h 15m  (1 stop)
# 81          13:20        17:55   Vistara   4h 35m  (1 stop)
# 82          11:10        16:00   Vistara   4h 50m  (1 stop)
#
#                                    layovers price(2019-8-11---8:32)
# 0     5h 50m in HYD\nStopover 5h 50m in HYD                 Rs6,106
# 1     2h 50m in AMD\nStopover 2h 50m in AMD                 Rs6,106
# 2     9h 55m in IXC\nStopover 9h 55m in IXC                 Rs6,106
# 3   13h 35m in IXC\nStopover 13h 35m in IXC                 Rs6,162
# 4       6h 5m in IXC\nStopover 6h 5m in IXC                 Rs6,162
# 5     4h 50m in AMD\nStopover 4h 50m in AMD                 Rs6,197
# 6   12h 15m in HYD\nStopover 12h 15m in HYD                 Rs6,197
# 7     3h 30m in HYD\nStopover 3h 30m in HYD                 Rs6,457
# 8     2h 25m in AMD\nStopover 2h 25m in AMD                 Rs6,457
# 9       3h 5m in HYD\nStopover 3h 5m in HYD                 Rs6,457
# 10    9h 15m in HYD\nStopover 9h 15m in HYD                 Rs6,457
# 11  15h 10m in HYD\nStopover 15h 10m in HYD                 Rs6,457
# 12  21h 35m in HYD\nStopover 21h 35m in HYD                 Rs6,583
# 13  11h 15m in HYD\nStopover 11h 15m in HYD                 Rs6,583
# 14  22h 55m in HYD\nStopover 22h 55m in HYD                 Rs6,583
# 15    2h 35m in IXC\nStopover 2h 35m in IXC                 Rs6,583
# 16    1h 30m in AMD\nStopover 1h 30m in AMD                 Rs6,651
# 17    7h 50m in HYD\nStopover 7h 50m in HYD                 Rs6,651
# 18    4h 10m in LKO\nStopover 4h 10m in LKO                 Rs6,651
# 19    3h 35m in PAT\nStopover 3h 35m in PAT                 Rs6,651
# 20    4h 20m in PAT\nStopover 4h 20m in PAT                 Rs6,794
# 21    4h 55m in LKO\nStopover 4h 55m in LKO                 Rs6,794
# 22    2h 15m in GOP\nStopover 2h 15m in GOP                 Rs6,854
# 23    3h 30m in GOI\nStopover 3h 30m in GOI                 Rs6,854
# 24      1h 5m in BLR\nStopover 1h 5m in BLR                 Rs6,854
# 25    1h 10m in BLR\nStopover 1h 10m in BLR                 Rs6,854
# 26    3h 45m in DED\nStopover 3h 45m in DED                 Rs6,854
# 27          40m in MAA\nStopover 40m in MAA                 Rs6,864
# 28    4h 25m in JLR\nStopover 4h 25m in JLR                 Rs6,864
# 29          45m in BLR\nStopover 45m in BLR                 Rs6,864
# ..                                      ...                     ...
# 53                                      NaN                 Rs9,729
# 54                                      NaN                 Rs9,746
# 55                                      NaN                 Rs9,867
# 56                                      NaN                Rs10,166
# 57                                      NaN                Rs10,254
# 58                                      NaN                Rs10,254
# 59                                      NaN                Rs10,254
# 60                                      NaN                Rs10,469
# 61                                      NaN                Rs10,469
# 62                                      NaN                Rs10,469
# 63                                      NaN                Rs10,469
# 64                                      NaN                Rs10,674
# 65                                      NaN                Rs10,674
# 66                                      NaN                Rs10,991
# 67                                      NaN                Rs11,266
# 68                                      NaN                Rs11,275
# 69                                      NaN                Rs11,418
# 70                                      NaN                Rs11,932
# 71                                      NaN                Rs11,932
# 72                                      NaN                Rs11,970
# 73                                      NaN                Rs14,366
# 74                                      NaN                Rs14,594
# 75                                      NaN                Rs14,941
# 76                                      NaN                Rs14,941
# 77                                      NaN                Rs14,982
# 78                                      NaN                Rs15,862
# 79                                      NaN                Rs16,463
# 80                                      NaN                Rs19,393
# 81                                      NaN                Rs20,865
# 82                                      NaN                Rs21,794
#
# [83 rows x 7 columns]

# %%
df.insert(loc=7, column='pred_price', value = 0 , allow_duplicates = False)

# %%
df

# %%
df.corr

# %%
a=datetime.datetime.now().time()

# %%
a

# %%
b =  datetime.time(23,  59,59, 999999)

# %%
b

# %%
if b>a:
    print ('sahil')

# %%
if a==b :
    link = 'https://www.expedia.co.in/'
    browser.get(link)
    time.sleep(5)
    #choose flights only
    flights_only = browser.find_element_by_xpath("//button[@id='tab-flight-tab-hp']")
    flights_only.click()
    ticket_chooser(return_ticket)
    dep_country_chooser('New Delhi')
    arrival_country_chooser('Mumbai')
    dep_date_chooser('15', '08', '2019')
    return_date_chooser('20', '08', '2019')
    search()
    compile_data()
    #save values for email
    current_values = df.iloc[0]
    cheapest_dep_time = current_values[0]
    cheapest_arrival_time = current_values[1]
    cheapest_airline = current_values[2]
    cheapest_duration = current_values[3]
    cheapest_stops = current_values[4]
    cheapest_price = current_values[-1]
    print('run {} completed!'.format(i))
    df.to_excel('flights.xlsx')
    
else:
    a=datetime.datetime.now().time()

# %%
a=

# %%
while a>b:
    print('sahil')
else:
    a=datetime.datetime.now().time()

# %%
a

# %%
b

# %%
x=5
y=4

# %%
for i in range (30):
    a=datetime.datetime.now().time()
    while a==b :
        print('victory')
        time.sleep(86375)
